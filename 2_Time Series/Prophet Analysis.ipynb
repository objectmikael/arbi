# %% [markdown]
# #Install the required libraries

# %%
# !pip install prophet
# !pip install hvplot
# !pip install holoviews
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 9.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Import the required libraries and dependencies

# %%
import pandas as pd
import holoviews as hv
from prophet import Prophet
import hvplot.pandas
import datetime as dt
# %matplotlib inline
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %% [markdown]
# # Setting `bokeh` to render hvPlot charts

# %%
hv.extension("bokeh")
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %% [markdown]
# #Load the data into the Dataframe

# %%
prophet_dataset = pd.read_csv(
    "prophet_dataset.csv"
).dropna()

# %% [markdown]
# ####Review the first and  last five rows of the df

# %%
display(prophet_dataset.head())
display(prophet_dataset.tail())
# Out:
#                     ds         y
# 0  2024-04-07 23:17:00  1.514719
# 1  2024-04-07 23:29:00  7.522615
# 2  2024-04-07 23:30:00  3.083893
# 3  2024-04-07 23:31:00  3.132775
# 4  2024-04-07 23:32:00  3.338795
#                        ds         y
# 6484  2024-04-16 11:41:00  7.289218
# 6485  2024-04-16 11:42:00  3.745812
# 6486  2024-04-16 11:43:00  3.826427
# 6487  2024-04-16 11:44:00  8.478174
# 6488  2024-04-16 11:45:00  9.078028

# %% [markdown]
# # Call the Prophet function and store as an object

# %%
m = Prophet()

# %% [markdown]
# # Fit the time series Prophet model

# %%
m.fit(prophet_dataset)
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfac2j6lm/3jphcplm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpfac2j6lm/tgwyg73p.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=52326', 'data', 'file=/tmp/tmpfac2j6lm/3jphcplm.json', 'init=/tmp/tmpfac2j6lm/tgwyg73p.json', 'output', 'file=/tmp/tmpfac2j6lm/prophet_model8uyn27a6/prophet_model-20240418011206.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:12:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:12:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %% [markdown]
# #Set Up for Predictions
# - Create a future DataFrame to hold predictions
# - Make the prediction go out as far as 2 days, 2880 minutes.

# %%
future = m.make_future_dataframe(periods=2880, freq='min')

# %% [markdown]
# #### Review the first and last 10 rows of the DataFrame

# %%
display(future.head(10))
display(future.tail(10))
# Out:
#                    ds
# 0 2024-04-07 23:17:00
# 1 2024-04-07 23:29:00
# 2 2024-04-07 23:30:00
# 3 2024-04-07 23:31:00
# 4 2024-04-07 23:32:00
# 5 2024-04-07 23:33:00
# 6 2024-04-07 23:34:00
# 7 2024-04-07 23:35:00
# 8 2024-04-07 23:36:00
# 9 2024-04-07 23:39:00
#                       ds
# 9359 2024-04-18 11:36:00
# 9360 2024-04-18 11:37:00
# 9361 2024-04-18 11:38:00
# 9362 2024-04-18 11:39:00
# 9363 2024-04-18 11:40:00
# 9364 2024-04-18 11:41:00
# 9365 2024-04-18 11:42:00
# 9366 2024-04-18 11:43:00
# 9367 2024-04-18 11:44:00
# 9368 2024-04-18 11:45:00

# %% [markdown]
# #Build a Table of Predictions
# - Make a forecast based on the future DataFrame

# %%
forecast = m.predict(future)

# %% [markdown]
# #### Review the first five rows of the forecast DataFrame

# %%
display(forecast.head())
display(forecast.tail())
# Out:
#                    ds       trend    yhat_lower    yhat_upper  trend_lower  \
# 0 2024-04-07 23:17:00 -391.491948 -2.904035e+06  7.720426e+06  -391.491948
# 1 2024-04-07 23:29:00  589.022586 -3.017084e+06  7.633561e+06   589.022586
# 2 2024-04-07 23:30:00  670.732130 -2.746695e+06  8.166101e+06   670.732130
# 3 2024-04-07 23:31:00  752.441675 -2.728670e+06  8.083387e+06   752.441675
# 4 2024-04-07 23:32:00  834.151219 -2.723392e+06  7.569451e+06   834.151219
#
#    trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  -391.491948    2.535191e+06          2.535191e+06          2.535191e+06
# 1   589.022586    2.513353e+06          2.513353e+06          2.513353e+06
# 2   670.732130    2.508496e+06          2.508496e+06          2.508496e+06
# 3   752.441675    2.503177e+06          2.503177e+06          2.503177e+06
# 4   834.151219    2.497395e+06          2.497395e+06          2.497395e+06
#
# ...

# %% [markdown]
# #Plot the Forecast
# - Plot the forecast using the model’s plot function

# %%
m.plot(forecast)

# %% [markdown]
# #Read the Forecast Results
# - Display the underlying forecast dataframe (tail)

# %%
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#                       ds           yhat    yhat_lower    yhat_upper
# 9364 2024-04-18 11:41:00  859326.872295 -6.290624e+07  6.596655e+07
# 9365 2024-04-18 11:42:00  856563.932046 -6.172629e+07  6.390759e+07
# 9366 2024-04-18 11:43:00  853647.355294 -6.276491e+07  6.478846e+07
# 9367 2024-04-18 11:44:00  850578.373000 -6.236677e+07  6.768247e+07
# 9368 2024-04-18 11:45:00  847358.272220 -6.172120e+07  6.727332e+07

# %% [markdown]
# # Plot the individual time series components of the model

# %%
fig2 = m.plot_components(forecast)

# %% [markdown]
# #Evaluation
